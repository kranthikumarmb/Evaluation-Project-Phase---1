# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# # Checking for Null values

# %%
df.isnull()
# Out:
#         W      R     AB      H     2B     3B     HR     BB     SO     SB  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# # checking for duplicate rows

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.shape
# Out:
# (30, 17)

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
df['W'].nunique()
# Out:
# 24

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [raw]
# visulalization of the data set with each columns

# %%
import seaborn as sbs

# %%
a1=sbs.countplot(x="AB",data=df)

# %%
a2=sbs.countplot(x="W",data=df)
print(df['W'].value_counts())
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
# scatter plot diagram
a3=sbs.scatterplot(x='RA',y='ER',data=df)

# %%
#line plot 
a4=sbs.lineplot(x='R',y='AB',data=df)

# %%
#bar plot
a5=sbs.barplot(x='H',y='2B',data=df)

# %%
#histogram
a6=sbs.histplot(x='3B',y='HR',data=df)

# %%
# box plot
a7=sbs.boxplot(x='BB',y='SO',data=df)

# %%
# violin plot
a8=sbs.violinplot(x='CG',y='SHO',data=df)

# %%
a9=sbs.jointplot(x='SV',y='E',data=df)
a9

# %%
# pair plot
a10=sbs.pairplot(data=df)
a10

# %%
# to check the distribution in  the form of visulization for the target variable 
sbs.distplot(df['W'],kde=True)
# Out:
# C:\Users\kranthi.kumar\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
# to ignore the wrnings like above we are importing the warnings functions
import warnings
warnings.filterwarnings('ignore')

# %%
# now we can see the warnings are not showing for the below distplots
sbs.distplot(df['W'],kde=True)
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
# by using the corr we can see the correlationship between the each of the columns 
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
# we are using the describe function to check the skewness and the other percentage functions 
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
import matplotlib.pyplot as mp

# %%
# we are creating heatmap for the decribe of the data set
mp.figure(figsize=(18,9))
sbs.heatmap(df.describe(),annot=True,linewidth=0.8,linecolor='purple',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
# we are creating the heat map for the correlation of the columns 
mp.figure(figsize=(19,8))
sbs.heatmap(df.corr(),annot=True,cmap='RdYlBu',linewidth=0.7,linecolor="yellow",fmt="0.1f")
# Out:
# <AxesSubplot:>

# %% [raw]
# in the above heatmap it shows us the correlation between the each columns , the dark blue color shows us the
# postive and high correlated columns , and the red shows us the negative correlation between the columns

# %% [raw]
# checking the columns  which are positively and negatively correlated with each other

# %%
mp.figure(figsize=(22,7))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='c')
# Out:
# <AxesSubplot:>

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
# we are using zscore to remove the outliers in the 
from scipy.stats import zscore
threshold=3
z=np.abs(zscore(df))
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
df_new.shape
# Out:
# (29, 17)

# %%
df.shape
# Out:
# (30, 17)

# %%
feature=df_new.drop('W',axis=1)
target=df_new['W']

# %%
feature.shape
# Out:
# (29, 16)

# %%
target.shape
# Out:
# (29,)

# %%
from sklearn.preprocessing import MinMaxScaler
mns=MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
lr=LinearRegression()
for i in range(0,100):
    feature_train,feature_test,target_train,target_test=train_test_split(feature,target,test_size=0.2,random_state=1)
    lr.fit(feature_train,target_train)
    pred_train=lr.predict(feature_train)
    pred_test=lr.predict(feature_test)
    print(f' At random state {i} , the traing accauracy is ; {r2_score(target_train,pred_train)}')
    print(f' at random state {i}, the testing accauracy is ; {r2_score(target_test,pred_test)}')
# Out:
#  At random state 0 , the traing accauracy is ; 0.9693516004448698
#  at random state 0, the testing accauracy is ; 0.7555241414909541
#  At random state 1 , the traing accauracy is ; 0.9693516004448698
#  at random state 1, the testing accauracy is ; 0.7555241414909541
#  At random state 2 , the traing accauracy is ; 0.9693516004448698
#  at random state 2, the testing accauracy is ; 0.7555241414909541
#  At random state 3 , the traing accauracy is ; 0.9693516004448698
#  at random state 3, the testing accauracy is ; 0.7555241414909541
#  At random state 4 , the traing accauracy is ; 0.9693516004448698
#  at random state 4, the testing accauracy is ; 0.7555241414909541
#  At random state 5 , the traing accauracy is ; 0.9693516004448698
#  at random state 5, the testing accauracy is ; 0.7555241414909541
#  At random state 6 , the traing accauracy is ; 0.9693516004448698
#  at random state 6, the testing accauracy is ; 0.7555241414909541
# ...

# %%
# training a model
lr.fit(feature_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(feature_test)

# %%
r2_score(target_test,pred_test)
# Out:
# 0.7555241414909541

# %% [raw]
# # cross validating

# %%
train_accuracy=r2_score(target_train,pred_train)
test_accuracy=r2_score(target_test,pred_test)
from sklearn.model_selection import cross_val_score
for kk in range(2,10):
    cv_score=cross_val_score(lr,feature,target,cv=kk)
    cv_mean=cv_score.mean()
    print (f' cross fold {kk} the cv score is {cv_mean} and the accuracy_score for training is {train_accuracy} and the accauracy for testing is {test_accuracy}')
# Out:
#  cross fold 2 the cv score is -2.128664455865708 and the accuracy_score for training is 0.9693516004448698 and the accauracy for testing is 0.7555241414909541
#  cross fold 3 the cv score is -1.0613861623999419 and the accuracy_score for training is 0.9693516004448698 and the accauracy for testing is 0.7555241414909541
#  cross fold 4 the cv score is -0.24334983064493676 and the accuracy_score for training is 0.9693516004448698 and the accauracy for testing is 0.7555241414909541
#  cross fold 5 the cv score is 0.037628660496460964 and the accuracy_score for training is 0.9693516004448698 and the accauracy for testing is 0.7555241414909541
#  cross fold 6 the cv score is -0.14490415472931853 and the accuracy_score for training is 0.9693516004448698 and the accauracy for testing is 0.7555241414909541
#  cross fold 7 the cv score is -0.16006807093965847 and the accuracy_score for training is 0.9693516004448698 and the accauracy for testing is 0.7555241414909541
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,6))
plt.scatter(x=target_test,y=pred_test,color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('actual wins ', fontsize=14)
plt.ylabel('predicted wins', fontsize=12)
plt.title('linear regression',fontsize=10)
plt.savefig('lr.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import Lasso
parameters={'alpha' :[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(feature_train,pred_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
# final model training 
ls=Lasso(alpha=1,random_state=0)
ls.fit(feature_train,target_train)
ls_score_training=ls.score(feature_train,target_train)
pred_ls=ls.predict(feature_test)
ls_score_training*100
# Out:
# 93.78000580980745

# %% [raw]
# ensemble techinique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(feature_train,target_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion="mse",max_features='auto')
rf.fit(feature_train,target_train)
rf.score(feature_train,target_train)
pred_decision=rf.predict(feature_test)
rfs=r2_score(target_test,pred_decision)
print('r2 score',rfs*100)
rfscore=cross_val_score(rf,feature,target,cv=5)
rfc=rfscore.mean()
print('cross val score ', rfc*100)
# Out:
# r2 score 69.56970167064439
# cross val score  -72.95077294869115

# %%
import pickle
filename='Baseball.pkl'
pickle.dump(ls,open(filename,'wb'))

# %% [markdown]
# conclusion

# %%
load_model=pickle.load(open('Baseball.pkl','rb'))
result=load_model.score(feature_test,target_test)
print(result*100)
# Out:
# 81.16156298132798

# %% [markdown]
# # Conclusion

# %% [markdown]
# * we have imported the required libraries
# * checked whether is their any null value missing value or white spaces in the data set
# * checked the correlation between the each column to understand the relationship between each columnn whether they are positive or negative
# * we have plotted the differnt plot to check the data flow in the form of visulization
# * violin plot , hist plot , countplot , line plot etc.
# * used the dist plot to check the distribution of the data
# * checked the columns which are positively and negatively correlated with each other
# * sacled the dataset with the help of the minmaxscaler
# * we cross vadilated the data for training and testing to trai the model to achieve good accuracy
# * did reguralization using the Lassso technique on the dataset and applied Grid Serach Cv function
# * ensemble the data we used again the random forest on the model we got good accauracy of 81%
# * saved the model by using the pickle technique
# * we cross vadidated the model and achieved the good accauracy
